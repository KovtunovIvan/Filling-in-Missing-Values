# %% [markdown]
# # Эксперимент №2
# https://archive.ics.uci.edu/ml/datasets/Parkinsons+Telemonitoring

# %%
import sys
import os

sys.path.append('..')
folder_path = os.path.abspath(os.path.join(os.getcwd(), "../../evaluate"))
sys.path.append(folder_path)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from tools import deletion_features
from tools import balancing
from tools import encoder
from tools import scaling
from Alg_CatBoost import CatBoostRegressor_fill 
from Alg_DecisionTree import DecisionTreeRegressor_fill
from Alg_Interpolate import interpolate_fill
from Alg_KNNImputer import KNNImputer_fill
from Alg_LinearRegression import LinearRegression_fill
from Alg_max import max_fill
from Alg_mean import mean_fill 
from Alg_median import median_fill
from Alg_min import min_fill
from Alg_RandomForestRegressor import RandomForestRegressor_fill
from Alg_SVR import SVR_fill
from Alg_XGBRegressor import XGBRegressor_fill
import results_metrics
import results_metrics_visualization

# %%
#считываем тренировочные данные
df = pd.read_csv('parkinsons_updrs.csv')

df.shape
# Out:
# (5875, 22)

# %% [markdown]
# # 1. Исследуем данные

# %%
df.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# 0       0.01309        0.01662      0.04314  0.014290  21.640  0.41888
# 1       0.01072        0.01689      0.02982  0.011112  27.183  0.43493
# 2       0.00844        0.01458      0.02202  0.020220  23.047  0.46222
# 3       0.01265        0.01963      0.03317  0.027837  24.445  0.48730
# 4       0.00929        0.01819      0.02036  0.011625  26.126  0.47188
#
#        DFA      PPE
# 0  0.54842  0.16006
# 1  0.56477  0.10810
# 2  0.54405  0.21014
# 3  0.57794  0.33277
# 4  0.56122  0.19361
#
# [5 rows x 22 columns]

# %%
#проверим данные на типы
df.dtypes
# Out:
# subject#           int64
# age                int64
# sex                int64
# test_time        float64
# motor_UPDRS      float64
# total_UPDRS      float64
# Jitter(%)        float64
# Jitter(Abs)      float64
# Jitter:RAP       float64
# Jitter:PPQ5      float64
# Jitter:DDP       float64
# Shimmer          float64
# Shimmer(dB)      float64
# Shimmer:APQ3     float64
# Shimmer:APQ5     float64
# Shimmer:APQ11    float64
# Shimmer:DDA      float64
# NHR              float64
# HNR              float64
# RPDE             float64
# DFA              float64
# PPE              float64
# dtype: object

# %%
#проверим на пропуски
df.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['subject#', 'age', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS',
#        'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5', 'Jitter:DDP',
#        'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 22

# %%
#построим корреляционную матрицу
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),cmap='YlGnBu', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2. Произведем предобработку данных

# %% [markdown]
# # 2.3. Устранение дубликатов

# %%
#проверяем наличие дубликатов и удаляем их
data = df.drop_duplicates()

# %% [markdown]
# # 2.5. Масштабирование данных

# %% [markdown]
# Произведем масштабирование данных

# %%
data = scaling.data_scaling(data)

# %%
data
# Out:
#       subject#       age       sex  test_time  motor_UPDRS  total_UPDRS  \
# 0    -1.656596  0.815695 -0.682509  -1.632090     0.849197     0.502745
# 1    -1.656596  0.815695 -0.682509  -1.500676     0.879706     0.549103
# 2    -1.656596  0.815695 -0.682509  -1.369410     0.910216     0.595367
# 3    -1.656596  0.815695 -0.682509  -1.257773     0.936051     0.634716
# 4    -1.656596  0.815695 -0.682509  -1.108169     0.970743     0.687522
# ...        ...       ...       ...        ...          ...          ...
# 5870  1.657546 -0.431361 -0.682509   0.934231     0.146246     0.417413
# 5871  1.657546 -0.431361 -0.682509   1.066152     0.085104     0.370962
# 5872  1.657546 -0.431361 -0.682509   1.196763     0.024453     0.324884
# 5873  1.657546 -0.431361 -0.682509   1.326064    -0.035582     0.279274
# 5874  1.657546 -0.431361 -0.682509   1.457050    -0.096355     0.233103
#
#       Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  \
# 0      0.082905    -0.284242    0.327453    -0.028637  ...    -0.351642
# 1     -0.560793    -0.756723   -0.533746    -0.476212  ...    -0.573156
# 2     -0.238944    -0.539382   -0.300038    -0.320767  ...    -0.564469
# 3     -0.155370    -0.485186   -0.344859    -0.170682  ...     0.069668
# 4     -0.498557    -0.663894   -0.658604    -0.529814  ...    -0.586186
# ...         ...          ...         ...          ...  ...          ...
# 5870  -0.372307    -0.358449   -0.421694    -0.427970  ...    -0.655681
# 5871  -0.566128    -0.537436   -0.575365    -0.484252  ...    -0.416793
# 5872  -0.473663    -0.537158   -0.469717    -0.377049  ...    -0.290834
# 5873  -0.594579    -0.658336   -0.546552    -0.473532  ...    -0.781639
# 5874  -0.592801    -0.637213   -0.524142    -0.433331  ...    -0.607903
#
#       Shimmer:APQ3  Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR  \
# 0        -0.209709     -0.423356      -0.543466    -0.209704 -0.298721
# 1        -0.545158     -0.565592      -0.529955    -0.545153 -0.351965
# 2        -0.741592     -0.702426      -0.645545    -0.741587 -0.199370
# 3        -0.460540     -0.449763      -0.392849    -0.460787 -0.071754
# 4        -0.783145     -0.651413      -0.464905    -0.783392 -0.343370
# ...            ...           ...            ...          ...       ...
# 5870     -0.561024     -0.528983      -0.600010    -0.560767 -0.116990
# 5871     -0.501338     -0.442561      -0.422372    -0.501081 -0.338311
# 5872     -0.260328     -0.335135      -0.435882    -0.260576 -0.241573
# 5873     -0.772568     -0.686822      -0.721104    -0.772815 -0.404372
# 5874     -0.581423     -0.516380      -0.639540    -0.581166 -0.401222
#
#            HNR      RPDE       DFA       PPE
# 0    -0.009205 -1.214066 -1.478500 -0.650658
# 1     1.282650 -1.055119 -1.247880 -1.218585
# 2     0.318711 -0.784860 -1.540139 -0.103280
# 3     0.644530 -0.536487 -1.062115  1.237075
# 4     1.036305 -0.689195 -1.297953 -0.283954
# ...        ...       ...       ...       ...
# 5870  0.160696  0.997028 -1.411923 -0.064697
# 5871  0.281189 -0.153430 -1.242097 -1.020641
# 5872  0.789028 -0.629379 -1.048856 -0.852755
# 5873  0.639170  0.269141 -1.269038 -0.847618
# 5874  0.368120  0.441754 -1.163249 -0.723890
#
# [5875 rows x 22 columns]

# %% [markdown]
# # 3. Работаем с пропусками

# %% [markdown]
# data - после предобработки данных был получен эталонный датасет с которым будет происходить сравнение по метрикам

# %%
data.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
data.shape
# Out:
# (5875, 22)

# %% [markdown]
# # 3.1. Искусственно создаем пропуски

# %%
# искусственно создаем пропуски в данных, которые впоследствии будем заполнять
# выбираем случайный признак
df_copy = data.copy()

random_feature = np.random.choice(df_copy.columns)

# %%
df1 = deletion_features.make_missing_value(df_copy, 0.05, random_feature)

# %%
#визуализируем наличие пропусков
plt.figure(figsize=(10,10))
sns.heatmap(pd.DataFrame(df1).isna().transpose(), cmap = "YlGnBu", cbar_kws={'label':'Missing Data'})
# Out:
# <AxesSubplot:>

# %%
df1.isna().sum()
# Out:
# subject#           0
# age                0
# sex                0
# test_time          0
# motor_UPDRS        0
# total_UPDRS        0
# Jitter(%)          0
# Jitter(Abs)        0
# Jitter:RAP         0
# Jitter:PPQ5        0
# Jitter:DDP         0
# Shimmer            0
# Shimmer(dB)        0
# Shimmer:APQ3       0
# Shimmer:APQ5     293
# Shimmer:APQ11      0
# Shimmer:DDA        0
# NHR                0
# HNR                0
# RPDE               0
# DFA                0
# PPE                0
# dtype: int64

# %% [markdown]
# создадим датасет с 15% пропусков для сравнения результатов заполнения

# %%
df15 = deletion_features.make_missing_value(df_copy, 0.2, random_feature)
df15.isna().sum()
# Out:
# subject#            0
# age                 0
# sex                 0
# test_time           0
# motor_UPDRS         0
# total_UPDRS         0
# Jitter(%)           0
# Jitter(Abs)         0
# Jitter:RAP          0
# Jitter:PPQ5         0
# Jitter:DDP          0
# Shimmer             0
# Shimmer(dB)         0
# Shimmer:APQ3        0
# Shimmer:APQ5     1175
# Shimmer:APQ11       0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# RPDE                0
# DFA                 0
# PPE                 0
# dtype: int64

# %%
df20 = deletion_features.make_missing_value(df_copy, 0.35, random_feature)
df20.isna().sum()
# Out:
# subject#            0
# age                 0
# sex                 0
# test_time           0
# motor_UPDRS         0
# total_UPDRS         0
# Jitter(%)           0
# Jitter(Abs)         0
# Jitter:RAP          0
# Jitter:PPQ5         0
# Jitter:DDP          0
# Shimmer             0
# Shimmer(dB)         0
# Shimmer:APQ3        0
# Shimmer:APQ5     2056
# Shimmer:APQ11       0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# RPDE                0
# DFA                 0
# PPE                 0
# dtype: int64

# %% [markdown]
# # 3.2. Заполняем пропуски

# %% [markdown]
# #1. Заполним пропуски средним арифметическим значением по признаку

# %%
df_mean_fill = mean_fill.mean_fill(df1)

# %%
df_mean_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #2. Заполним пропуски медианным значением по признаку

# %%
df_median_fill = median_fill.median_fill(df1)
df_median_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #3. Заполним пропуски минимальным значением по признаку

# %%
df_min_fill = min_fill.min_fill(df1)
df_min_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #4. Заполним пропуски максимальным значением по признаку

# %%
df_max_fill = df_min_fill = max_fill.max_fill(df1)
df_max_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #5. Заполним пропуски используя интерполяцию

# %% [markdown]
# интерполяция даже при 10% пропусков по признакам не в состоянии восстановить все значения (напишем свой алгоритм заполнения на основе интерполяции)

# %%
df_interpolate_fill = interpolate_fill.interpolate_fill(df1)
df_interpolate_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #6. Заполним пропуски используя линейную регрессию

# %%
df_LinearReg_fill = LinearRegression_fill.linreg_imputer(df1)
df_LinearReg_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #7 Заполним пропуски используя KNNImputer

# %% [markdown]
# KNNImputer при 15% пропусков по признаку не смог восстановить все значения (напишем свой алгоритм заполнения на основе KNN)

# %%
df_KNNImputer_fill = KNNImputer_fill.KNNImputer_fill(df1)
df_KNNImputer_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #8 Заполним пропуски используя дерево решений

# %%
df_DecisionTree_fill = DecisionTreeRegressor_fill.DecisionTree_imputer(df1)
df_DecisionTree_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #9 Заполним пропуски используя случайный лес

# %%
df_RandomForest_fill = RandomForestRegressor_fill.RandomForest_imputer(df1)
df_RandomForest_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #10 Заполним пропуски используя SVM

# %%
df_SVM_fill = SVR_fill.SVM_imputer(df1)
df_SVM_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #11 Заполним пропуски используя градиентный бустинг - XGboost

# %%
df_XGBRegressor_fill = XGBRegressor_fill.XGBRegressor_imputer(df1)
df_XGBRegressor_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# #12 Заполним пропуски используя градиентный бустинг - CatBoost

# %%
df_CatBoostRegressor_fill = CatBoostRegressor_fill.CatBoostRegressor_imputer(df1)
df_CatBoostRegressor_fill.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
data.isna().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# subject#           0
# age                0
# sex                0
# test_time          0
# motor_UPDRS        0
# total_UPDRS        0
# Jitter(%)          0
# Jitter(Abs)        0
# Jitter:RAP         0
# Jitter:PPQ5        0
# Jitter:DDP         0
# Shimmer            0
# Shimmer(dB)        0
# Shimmer:APQ3       0
# Shimmer:APQ5     293
# Shimmer:APQ11      0
# Shimmer:DDA        0
# NHR                0
# HNR                0
# RPDE               0
# DFA                0
# PPE                0
# dtype: int64

# %% [markdown]
# # 4. Формируем результаты эксперимента

# %%
all_methods = [df_mean_fill, df_median_fill, df_min_fill, df_max_fill, df_interpolate_fill, df_LinearReg_fill, df_KNNImputer_fill, df_DecisionTree_fill, df_RandomForest_fill, df_SVM_fill, df_XGBRegressor_fill, df_CatBoostRegressor_fill]
df1_result = results_metrics.generate_results_metrics(data, all_methods)
df1_result
# Out:
#                    Mean_absolute_error  Mean_squared_error  r2_score
# Mean                          0.001357            0.002247  0.997636
# Median                        0.001242            0.002373  0.997512
# Min                           0.020021            0.179063  0.961339
# Max                           0.020021            0.179063  0.961339
# Interpolate                   0.000932            0.001122  0.998874
# LinearReg                     0.000168            0.000054  0.999946
# KNNImputer                    0.000278            0.000098  0.999902
# DecisionTree                  0.000199            0.000072  0.999928
# RandomForest                  0.000158            0.000058  0.999941
# SVM                           0.000162            0.000047  0.999953
# XGBRegressor                  0.000150            0.000048  0.999952
# CatBoostRegressor             0.000148            0.000049  0.999951

# %%
results_metrics_visualization.visualization_results_metrics(df1_result)

# %%
all_methods = [mean_fill.mean_fill(df15), median_fill.median_fill(df15), min_fill.min_fill(df15), max_fill.max_fill(df15), interpolate_fill.interpolate_fill(df15),
              LinearRegression_fill.linreg_imputer(df15), KNNImputer_fill.KNNImputer_fill(df15), DecisionTreeRegressor_fill.DecisionTree_imputer(df15),
              RandomForestRegressor_fill.RandomForest_imputer(df15), SVR_fill.SVM_imputer(df15), XGBRegressor_fill.XGBRegressor_imputer(df15), CatBoostRegressor_fill.CatBoostRegressor_imputer(df15)]
df15_result = results_metrics.generate_results_metrics(data, all_methods)
df15_result
# Out:
#                    Mean_absolute_error  Mean_squared_error  r2_score
# Mean                          0.005602            0.009753  0.987584
# Median                        0.005250            0.010449  0.986871
# Min                           0.010097            0.020963  0.978497
# Max                           0.079969            0.713202  0.946093
# Interpolate                   0.004061            0.005538  0.994171
# LinearReg                     0.000680            0.000252  0.999749
# KNNImputer                    0.001175            0.000437  0.999558
# DecisionTree                  0.000963            0.000611  0.999402
# RandomForest                  0.000655            0.000278  0.999723
# SVM                           0.000814            0.000730  0.999243
# XGBRegressor                  0.000658            0.000287  0.999717
# CatBoostRegressor             0.000602            0.000210  0.999791

# %%
results_metrics_visualization.visualization_results_metrics(df15_result)

# %%
all_methods = [mean_fill.mean_fill(df20), median_fill.median_fill(df20), min_fill.min_fill(df20), max_fill.max_fill(df20), interpolate_fill.interpolate_fill(df20), 
              LinearRegression_fill.linreg_imputer(df20), KNNImputer_fill.KNNImputer_fill(df20), DecisionTreeRegressor_fill.DecisionTree_imputer(df20),
              RandomForestRegressor_fill.RandomForest_imputer(df20), SVR_fill.SVM_imputer(df20), XGBRegressor_fill.XGBRegressor_imputer(df20), CatBoostRegressor_fill.CatBoostRegressor_imputer(df20)]
df20_result = results_metrics.generate_results_metrics(data, all_methods)
df20_result
# Out:
#                    Mean_absolute_error  Mean_squared_error  r2_score
# Mean                          0.009686            0.015917  0.975510
# Median                        0.009160            0.017187  0.974143
# Min                           0.017683            0.035561  0.961194
# Max                           0.139913            1.246527  0.932132
# Interpolate                   0.007456            0.009927  0.989846
# LinearReg                     0.001148            0.000368  0.999635
# KNNImputer                    0.002083            0.000747  0.999248
# DecisionTree                  0.001613            0.000846  0.999169
# RandomForest                  0.001152            0.000482  0.999523
# SVM                           0.001399            0.000930  0.999021
# XGBRegressor                  0.001172            0.000458  0.999553
# CatBoostRegressor             0.001063            0.000315  0.999688

# %%
results_metrics_visualization.visualization_results_metrics(df20_result)
